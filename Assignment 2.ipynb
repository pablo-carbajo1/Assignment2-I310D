# %%
import matplotlib.pyplot as plt
import pandas as pd
import time

df = pd.read_csv('labeled_and_scored_comments.csv')

# %% [markdown]
# ## General table for all the comments in the dataset
#
#
# From the table below we can see that this dataset includes 41,338 comments. There are also 9 columns which are: id (which is unique for each comment), comment_text, score (0 being not toxic at all and 1 being the most toxic), and the other columns use binary numbers as their data type and they are: toxic, severe_toxic, obscene, threat, insult and identity_hate.

# %%
df.sort_values('score')
# Out:
#                      id                                       comment_text  \
# 1158   61a85266de70cca0                         Можешь говорить по русски.
# 5246   030a9ba0b32b4456  Rodzina Krusenstern Potomkowie Admirała Adama ...
# 11040  a6814193ac6b4705  The opening paragraph states that the game is ...
# 24192  f0d6dee96e057a5b  The book is used as a source in a number of ar...
# 2332   cbb9268d3c7429c1     Vals Vienés \n |Rumba \n |Cha Cha Chá(ciclo 7)
# ...                 ...                                                ...
# 19994  1429a2c930688317                          you fucking piece of shit
# 28728  d82e45eb103ad07b                   fuck off you stupid aspy asshole
# 25535  e9b92c6c6b01aeef  FUCK YOU YOU PIECE OF SHIT \n FUCK YOU YOU PIE...
# 25945  e783fd267f3a9d3b  FUCK WIKIPEDIA ON WHEELS! \n\nFuck off wikiped...
# 17833  364b6c24210e2345  Fuck you you fucking pig!\n\nYou motherfucking...
#
# ...

# %%
plt.hist(df['score'])
plt.show()

# %% [markdown]
# ## Table for  toxic comments
#
# I decided to create a table (see below) for all the comments that are classified as toxic (in table: severe_toxic = 1). As we can see at the bottom of the table, there are 3943 rows in this table. Which shows that out of 41,338 comments there are 3943 comments that are severely toxic.
#
# $ \frac{3943}{41338} * 100 \approx 9.5  $
#
# As we can see from the calculation above, the comments that are classified as  toxic are 9.5% of the total comments. This means that almost 1 out of 10 comments is hateful and toxic.

# %%
sub_df = df.loc[df['toxic']==1]
sub_df
# Out:
#                      id                                       comment_text  \
# 8      00091c35fa9d0465  == Arabs are committing genocide in Iraq, but ...
# 24     0013fed3aeae76b7  DJ Robinson is gay as hell! he sucks his dick ...
# 29     0017d4d47894af05               :Fuck off, you anti-semitic cunt.  |
# 37     001d739c97bc2ae4  How dare you vandalize that page about the HMS...
# 38     001eff4007dbb65b  ::No, he is an arrogant, self serving, immatur...
# ...                 ...                                                ...
# 41297  94a6beeb87ab68c0               Damn, those are some rancid sources.
# 41299  94a5024323152cd1  ==Why does it bother you, fuckface?89.123.100....
# 41325  948cb4052152869b  WHAT?  That's past stuff.  Stop being an insti...
# 41332  9481cd7393b583c9  RE: \n\nIt's a fucking album cover, how the fu...
# 41333  9480bff99f91a69e  Lesbian Teenager \nHow about the fact she was ...
#
# ...

# %% [markdown]
# ## Table sorting toxic comments by score
#
# The following table sorts the toxic comments by their score from lowest to highest score.

# %%
df[df['toxic']==1].sort_values(['score'])
# Out:
#                      id                                       comment_text  \
# 34556  b8faa0ed6f557ad9  And we have a winner for the douchiest comment...
# 30103  d0bae6a8c78773bf  Look, what's your problem, kid? Have you got s...
# 15367  5f04a07ebb59fa3d  Alansohn tucks his sack back every now and the...
# 19650  1942efd2dad5e9c5             You need to end this now, cold turkey.
# 38493  a39b4836714430a1  SMOKE WEED ERRYDAY RIGHT BEFORE CLASS....PROFE...
# ...                 ...                                                ...
# 19994  1429a2c930688317                          you fucking piece of shit
# 28728  d82e45eb103ad07b                   fuck off you stupid aspy asshole
# 25535  e9b92c6c6b01aeef  FUCK YOU YOU PIECE OF SHIT \n FUCK YOU YOU PIE...
# 25945  e783fd267f3a9d3b  FUCK WIKIPEDIA ON WHEELS! \n\nFuck off wikiped...
# 17833  364b6c24210e2345  Fuck you you fucking pig!\n\nYou motherfucking...
#
# ...

# %% [markdown]
# ## Table for severely toxic comments
#
# I decided to create a table (see below) for all the comments that are classified as severely toxic (in table: severe_toxic = 1). As we can see at the bottom of the table, there are 379 rows in this table. Which shows that out of 41,338 comments there are 379 comments that are severely toxic.
#
# $ \frac{379}{41338} * 100 \approx 0.92  $
#
# As we can see from the calculation above, the comments that are classified as severely toxic are only 0.92% of the total comments. Even though, 0.92% is a very small number it is still too much. Software detection should be able to delete toxic comments.

# %%
df.loc[df['severe_toxic'] == 1]
# Out:
#                      id                                       comment_text  \
# 330    1a3ffaa9e319104c  ==Yo mama== \n This is yo mama and I know that...
# 332    1a44cad92a0c1c96  ==Son of a bitch== \n\n Hey you fucking neo-Na...
# 338    1a4c6302cea3ffe2  Dick Cheney will fucking kill all of those god...
# 430    20cdeb8ee999a478  == You know what smart arrse........phuck a bi...
# 447    2412ef2ce6f87a73  SSJ, the only way that fucking pitiful excuse ...
# ...                 ...                                                ...
# 41017  9622c82f97eb26cd  She is a Motherfucker \n\nI will block you Mot...
# 41053  95eda78799f2f83c  i forgot to sign \nReed210 \n\nPS Does your di...
# 41071  95ca65d4cd31d3dd  HOPE YOUR HEAD GETS CUT OFF AND SOMEONE WIPES ...
# 41181  95390a4e0cd90ad3  Fuck You Asshole \n\nFuck You, you cum-guzzlin...
# 41237  94f8578325d529ad  LMAO WHAT WEAK THREATS, I HAVENT BEEN BANNED Y...
#
# ...

# %% [markdown]
# ## Table sorting the severely toxic comments by score
#
# The following table sorts the severely toxic comments by their score from lowest to highest score.

# %%
df[df['severe_toxic']==1].sort_values(['score'])
# Out:
#                      id                                       comment_text  \
# 27263  e0539a647a5ed61d  War CriminalWar CriminalWar CriminalWar Crimin...
# 33118  c0e076f0011acaa6  "FFFFF UUUUUU CCCCCC KKKKKK ===== YOU! F UU C ...
# 28910  d73516d5de7f7384  big>I HATE Nl33ERS\nI HATE Nl33ERS\nI HATE Nl3...
# 17101  41fe17d86e765e7b  WIKI NAZI! \n\nThat's all you are, you even re...
# 25371  eab35a94edfe8946  Remeber rahmatul lil alameen? You Sunni monkey...
# ...                 ...                                                ...
# 6964   e88321c89a619419     Stupid fucking bitch rot in hell piece of shit
# 19994  1429a2c930688317                          you fucking piece of shit
# 28728  d82e45eb103ad07b                   fuck off you stupid aspy asshole
# 25535  e9b92c6c6b01aeef  FUCK YOU YOU PIECE OF SHIT \n FUCK YOU YOU PIE...
# 25945  e783fd267f3a9d3b  FUCK WIKIPEDIA ON WHEELS! \n\nFuck off wikiped...
#
# ...

# %%
from googleapiclient.discovery import build
import json

def get_toxicity_score(comment):
    
    API_KEY = 'AIzaSyCehbHYgYEwgfd6bcrxkG7tb0WSQxZ3cy4'
    
    client = build(
    "commentanalyzer"
    "v1alpha1",
    developerKey=API_KEY,
    discoveryServiceUrl="https://commentanalyzer.googleapis.com/$discovery/rest?version=v1alpha1",
    static_discovery=False,
    version=2.0,
    )
    
    analyze_request = {
    'comment': {'text' : comment }, 
    'requestedAttributes': {'TOXICITY': {}}
    }
    
    response = client.comments().analyze(body=analyze_request).execute()
    toxicity_score = response["attributeScores"]["TOXICITY"]["summaryScore"]["value"]
    
    return toxicity_score

# %% [markdown]
# #### Trying the Perpesctive API function

# %%
get_toxicity_score('Hey, Thanks for giving me a smile with some of your links. For instance Wikipedia:WikiProject Baiting Maggie')
# Out:
# 0.07350313

# %% [markdown]
# #### My hypothesis
#
# When you use symbols in swear words it is called a grawlix. For this assignment, I wanted to test if comments that include grawlixs have a lower toxicity score and then draw conclusions from the software that detects these toxicity scores. I am also going to test when swear words are typed correctly and compare them to compare them to comments that include these swear words typed correctly.

# %% [markdown]
# #### First example: fuck / f*ck

# %%
get_toxicity_score("Virgin My only warning? You'll block me? Well f*ck off. You probably get off from warning people on Wikipedia, don't you? I bet you're still a virgin, f*cking homo. As for your warning, shove it up your ass. and F*CK YOU!")
# Out:
# 0.94992846

# %%
get_toxicity_score('Fuck Off! Fuck Off!')
# Out:
# 0.9897058

# %% [markdown]
# #### Second example: suck my balls / lick ma ballens

# %%
get_toxicity_score('Suck my balls See title')
# Out:
# 0.9695766

# %%
get_toxicity_score('man u suck, lick ma ballen.')
# Out:
# 0.92197925

# %% [markdown]
# #### Third example: asshole / assole

# %%
get_toxicity_score("Geniac is an assole and a mom fuker..")
# Out:
# 0.94926727

# %%
get_toxicity_score("As I said, you're an asshole and that's all there is to it.")
# Out:
# 0.96897316

# %% [markdown]
# As we can see, all 3 toxicity scores were either misspelled or had symbols instead of letters inside the words.
